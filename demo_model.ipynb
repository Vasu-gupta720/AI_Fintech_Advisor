# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasu-gupta720/AI_Fintech_Advisor/blob/main/demo_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05
)

model = get_peft_model(model, lora_config)
# Out:
# /usr/local/lib/python3.12/dist-packages/peft/mapping_func.py:72: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:285: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05
)

model = get_peft_model(model, lora_config)
# Out:
# /usr/local/lib/python3.12/dist-packages/peft/mapping_func.py:72: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:285: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(

# %%
# !pip install transformers datasets peft accelerate bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 19.3 MB/s eta 0:00:00
# ...

# %%
import json

data = [
    {
        "instruction": "Analyze financial data and provide advice",
        "input": "Income: 40000, Expenses: 35000, Savings: 20000, Debt: 5000, Risk: Low, Goal: Travel, Horizon: Short",
        "output": """1. Financial Summary
* Income: 40000
* Expenses: 35000
* Savings: 20000
* Debt: 5000
* Risk Level: Low

2. Key Insights
* Positive cash flow
* Savings below emergency fund level
* Debt present

3. Recommendations
* Budgeting Strategy: Maintain controlled spending
* Savings Plan: Focus on building emergency fund
* Investment Advice: Capital protection focus
* Debt Management: Prioritize debt repayment

4. Expected Outcome
Improved financial stability based on dataset patterns.

5. Limitations
Advice is based only on available dataset and may not reflect real-world market conditions."""
    }
]

with open("data.json", "w") as f:
    json.dump(data, f)

# %%
import json
import random

def generate_sample():
    income = random.randint(25000, 100000)
    expenses = random.randint(20000, 90000)
    savings = random.randint(2000, 300000)
    debt = random.choice([0, random.randint(2000, 50000)])
    risk = random.choice(["Low", "Medium", "High"])
    goal = random.choice(["Travel", "Emergency Fund", "Wealth Growth", "House", "Education"])
    horizon = random.choice(["Short", "Medium", "Long"])

    insights = []
    if expenses > income:
        insights.append("Expenses exceed income")
    else:
        insights.append("Positive cash flow")

    if savings < 3 * expenses:
        insights.append("Savings below emergency fund level")
    else:
        insights.append("Adequate savings buffer")

    if debt > 0:
        insights.append("Debt present")
    else:
        insights.append("No debt")

    # Recommendations
    if expenses > income:
        budgeting = "Reduce expenses immediately"
    else:
        budgeting = "Maintain controlled spending"

    if savings < 3 * expenses:
        savings_plan = "Focus on building emergency fund"
    else:
        savings_plan = "Continue structured savings"

    if debt > 0:
        investment = "Avoid investments until debt is reduced"
    else:
        if risk == "Low":
            investment = "Low-risk strategy"
        elif risk == "Medium":
            investment = "Balanced strategy"
        else:
            investment = "Growth-focused strategy"

    if horizon == "Short":
        investment = "Capital protection focus"

    if debt > 0:
        debt_mgmt = "Prioritize debt repayment"
    else:
        debt_mgmt = "No debt management needed"

    output = f"""1. Financial Summary
* Income: {income}
* Expenses: {expenses}
* Savings: {savings}
* Debt: {debt}
* Risk Level: {risk}

2. Key Insights
* {insights[0]}
* {insights[1]}
* {insights[2]}

3. Recommendations
* Budgeting Strategy: {budgeting}
* Savings Plan: {savings_plan}
* Investment Advice: {investment}
* Debt Management: {debt_mgmt}

4. Expected Outcome
Improved financial stability and alignment with goals based on dataset patterns.

5. Limitations
Advice is based only on available dataset and may not reflect real-world market conditions."""

    return {
        "instruction": "Analyze financial data and provide advice",
        "input": f"Income: {income}, Expenses: {expenses}, Savings: {savings}, Debt: {debt}, Risk: {risk}, Goal: {goal}, Horizon: {horizon}",
        "output": output
    }

data = [generate_sample() for _ in range(200)]

with open("data.json", "w") as f:
    json.dump(data, f)

print("Dataset created with 200 samples")
# Out:
# Dataset created with 200 samples

# %%
# !pip install transformers datasets peft accelerate bitsandbytes

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "mistralai/Mistral-7B-v0.1"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    load_in_4bit=True
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1588/4122740096.py in <cell line: 0>()
#       5 tokenizer = AutoTokenizer.from_pretrained(model_name)
#       6
# ----> 7 model = AutoModelForCausalLM.from_pretrained(
#       8     model_name,
#       9     device_map="auto",
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     370             if model_class.config_class == config.sub_configs.get("text_config", None):
#     371                 config = config.get_text_config()
# --> 372             return model_class.from_pretrained(
#     373                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     374             )
#
# ...

# %% [markdown]
# ### Hugging Face Authentication
# To download models from the Hub, especially restricted ones, you should log in. Paste your token from [HF Settings](https://huggingface.co/settings/tokens) when prompted below.

# %%
from huggingface_hub import notebook_login

# This will create an input field for your HF Token
notebook_login()

# %% [markdown]
# After logging in, you can re-run the model loading cell. If you prefer not to log in every time, add your token to the Colab 'Secrets' (key icon on the left) with the name `HF_TOKEN`.

# %%
import json
import random

def generate_sample():
    income = random.randint(25000, 100000)
    expenses = random.randint(20000, 90000)
    savings = random.randint(2000, 300000)
    debt = random.choice([0, random.randint(2000, 50000)])
    risk = random.choice(["Low", "Medium", "High"])
    goal = random.choice(["Travel", "Emergency Fund", "Wealth Growth", "House", "Education"])
    horizon = random.choice(["Short", "Medium", "Long"])

    insights = []
    if expenses > income:
        insights.append("Expenses exceed income")
    else:
        insights.append("Positive cash flow")

    if savings < 3 * expenses:
        insights.append("Savings below emergency fund level")
    else:
        insights.append("Adequate savings buffer")

    if debt > 0:
        insights.append("Debt present")
    else:
        insights.append("No debt")

    # Recommendations
    if expenses > income:
        budgeting = "Reduce expenses immediately"
    else:
        budgeting = "Maintain controlled spending"

    if savings < 3 * expenses:
        savings_plan = "Focus on building emergency fund"
    else:
        savings_plan = "Continue structured savings"

    if debt > 0:
        investment = "Avoid investments until debt is reduced"
    else:
        if risk == "Low":
            investment = "Low-risk strategy"
        elif risk == "Medium":
            investment = "Balanced strategy"
        else:
            investment = "Growth-focused strategy"

    if horizon == "Short":
        investment = "Capital protection focus"

    if debt > 0:
        debt_mgmt = "Prioritize debt repayment"
    else:
        debt_mgmt = "No debt management needed"

    output = f"""1. Financial Summary
* Income: {income}
* Expenses: {expenses}
* Savings: {savings}
* Debt: {debt}
* Risk Level: {risk}

2. Key Insights
* {insights[0]}
* {insights[1]}
* {insights[2]}

3. Recommendations
* Budgeting Strategy: {budgeting}
* Savings Plan: {savings_plan}
* Investment Advice: {investment}
* Debt Management: {debt_mgmt}

4. Expected Outcome
Improved financial stability and alignment with goals based on dataset patterns.

5. Limitations
Advice is based only on available dataset and may not reflect real-world market conditions."""

    return {
        "instruction": "Analyze financial data and provide advice",
        "input": f"Income: {income}, Expenses: {expenses}, Savings: {savings}, Debt: {debt}, Risk: {risk}, Goal: {goal}, Horizon: {horizon}",
        "output": output
    }

data = [generate_sample() for _ in range(200)]

with open("data.json", "w") as f:
    json.dump(data, f)

print("Dataset created with 200 samples")
# Out:
# Dataset created with 200 samples

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import torch

model_name = "mistralai/Mistral-7B-v0.1"

# Configure 4-bit quantization
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True
)

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto"
)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05
)

model = get_peft_model(model, lora_config)
# Out:
# /usr/local/lib/python3.12/dist-packages/peft/mapping_func.py:72: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py:285: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(

# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files="data.json")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
def tokenize(example):
    text = example["instruction"] + "\n" + example["input"] + "\n" + example["output"]
    return tokenizer(text, truncation=True, padding="max_length")

dataset = dataset.map(tokenize)
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
from transformers import TrainingArguments, Trainer

# Set the padding token to the EOS token
tokenizer.pad_token = tokenizer.eos_token

# Update tokenization to include labels
def tokenize_with_labels(example):
    text = example["instruction"] + "\n" + example["input"] + "\n" + example["output"]
    tokenized = tokenizer(text, truncation=True, padding="max_length", max_length=512)
    tokenized["labels"] = tokenized["input_ids"].copy()
    return tokenized

# Re-map the dataset
dataset = dataset.map(tokenize_with_labels, remove_columns=dataset["train"].column_names)

training_args = TrainingArguments(
    output_dir="./finetuned",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    logging_steps=10,
    save_strategy="no",
    remove_unused_columns=False
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"]
)

trainer.train()
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 15:36, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.671562</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.710427</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.514183</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.314395</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.190805</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.149972</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.125023</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.119015</td>
#     </tr>
#     <tr>
#       <td>90</td>
# ...

# %%
input_text = "Income: 50000, Expenses: 45000, Savings: 10000, Debt: 5000, Risk: Low, Goal: Travel, Horizon: Short"

inputs = tokenizer(input_text, return_tensors="pt").to("cuda")

output = model.generate(**inputs, max_new_tokens=300)

print(tokenizer.decode(output[0]))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> Income: 50000, Expenses: 45000, Savings: 10000, Debt: 5000, Risk: Low, Goal: Travel, Horizon: Short
#
# 1. Budgeting Strategy
# * Balance Income and Expenses
# * Reduce Expenses below Income
# * Savings Funding
# * Debt Repayment
#
# 2. Investment Strategy
# * Capital Protection Focus
# * Low-Risk Asset Allocation
# * Focus on Capital Preservation
#
# 3. Savings Plan
# * Continue Savings
# * Aligned with Goals
# * Balance Liquidity and Growth
#
# 4. Risk Management
# * Capital Protection Focus
# * Downside Protection
# * Focus on Principal Protection
#
# 5. Tax Optimization
# * Capital Gains Minimization
# * Tax-Efficient Withdrawals
# * Aligned with Tax Rules
#
# 6. Estate Planning
# * Aligned with Wealth Transfer Goals
# * Balance Liquidity and Growth
# * Tax Efficiency Considerations
#
# 7. Financial Advice
# * Customized Strategy
# * Risk Management Focus
# * Aligned with Goals and Horizon</s>

# %%
model.save_pretrained("financial-advisor-llm")
tokenizer.save_pretrained("financial-advisor-llm")
# Out:
# ('financial-advisor-llm/tokenizer_config.json',
#  'financial-advisor-llm/tokenizer.json')
